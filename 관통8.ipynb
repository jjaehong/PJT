# %% [markdown]
# ## Django에서 알고리즘 구현 및 성능 측정(테스트 & 성능 테스트)

# %% [markdown]
# #### 1. 테스트 & 성능 테스트 개념
#
# 1. 테스트
#
#     - 원하는 기능이 모두 구현되었는지 확인하고, 숨겨져 있는 결함을 찾는 활동
#
#     - 여러가지 도구들을 활용하여 버그를 찾아내고 신뢰성, 보안, 성능 등을 검증하는 중요한 단계
#
#     - 테스트의 종류는 너무 많기에(100개 이상).. **상황에 맞게 필요한 테스트를 진행해야한다.**
#
#         - 외우지 말고 검색을 통해 필요한 것만 찾아서 사용해야 한다.
#
#
# 2. 성능 테스트
#
#     - 핵심적인 테스트 중 하나
#
#     - 특정 상황에서 시스템이 어느 정도 수준을 보이는가(나쁜 상황 주고) 혹은 어떻게 대처를 하는가를 테스트하는 과정(그래픽, 성능)
#
#     - 목적 :
#
#         - 여러 테스트를 통해 성능 저하가 발생하는 요인을 발견하고 제거
#
#         - 시장에 출시되기 전에 발생할 수 있는 위험과 개선사항을 파악
#
#         - 안정적이고 신뢰할 수 있는 제품을 빠르게 만들기 위함
#
#
#     ![이미지](이미지/성능테스트.PNG)
#
#     - 성능 테스트의 종류도 많다
#
#     - 그 중, 프로젝트에서는 핵심인 **부하 테스트**와 스트레스 테스트를 배운다.
#
#
#     ![이미지](이미지/부하%20테스트.PNG)
#
#     ![이미지](이미지/스트레스%20테스트.PNG)
#
#     ![이미지](이미지/부하vs스트레스.PNG)

# %% [markdown]
# #### 2. Locust 세팅(API 성능 테스트)
#
# - 오픈 소스 부하 테스트 도구(Locust, JMeter 등등)
#
# - 내가 만든 서버에 수많은 사용자(메뚜기)들이 동시에 들어올 때 어떤 일이 벌어지는 지 확인하는 부하 테스트를 할 수 있는 도구
#
# - Locust 선택 이유
#
#     - **파이썬 언어**로 테스트 시나리오 작성
#
#     - 결과를 웹에서 확인할 수 있는 UI 지원

# %% [markdown]
# #### 3. 정렬 알고리즘 성능 측정 실습
